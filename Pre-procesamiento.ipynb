# %%
# Ignorar warnings

import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("default")

# %%
# %pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# C:\Users\sebas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedWriter name=3>
#   return process_handler(cmd, _system_body)
# ...
# C:\Users\sebas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=4>
#   return process_handler(cmd, _system_body)
# ...
# C:\Users\sebas\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=5>
#   return process_handler(cmd, _system_body)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
import scipy
import math

# %%
# Lectura de archivo csv
df_generaldata = pd.read_csv("https://raw.githubusercontent.com/juantoro5/Analitica-para-RH-E7/main/general_data.csv", sep=",")
df_managersurvey = pd.read_csv("https://raw.githubusercontent.com/juantoro5/Analitica-para-RH-E7/main/manager_survey.csv", sep=",")
df_employeesurvey = pd.read_csv("https://raw.githubusercontent.com/juantoro5/Analitica-para-RH-E7/main/employee_survey_data.csv", sep=",")
df_retirement = pd.read_csv("https://raw.githubusercontent.com/juantoro5/Analitica-para-RH-E7/main/retirement_info.csv", sep=",")

# %%
df_generaldata
# Out:
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 0      51      Travel_Rarely                   Sales                 6
# 1      31  Travel_Frequently  Research & Development                10
# 2      32  Travel_Frequently  Research & Development                17
# 3      38         Non-Travel  Research & Development                 2
# 4      32      Travel_Rarely  Research & Development                10
# ...   ...                ...                     ...               ...
# 8815   42      Travel_Rarely  Research & Development                 5
# 8816   29      Travel_Rarely  Research & Development                 2
# 8817   25      Travel_Rarely  Research & Development                25
# 8818   42      Travel_Rarely                   Sales                18
# 8819   40      Travel_Rarely  Research & Development                28
#
#       Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# ...

# %%
df_generaldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8820 entries, 0 to 8819
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      8820 non-null   int64
#  1   BusinessTravel           8820 non-null   object
#  2   Department               8820 non-null   object
#  3   DistanceFromHome         8820 non-null   int64
#  4   Education                8820 non-null   int64
#  5   EducationField           8820 non-null   object
#  6   EmployeeCount            8820 non-null   int64
#  7   EmployeeID               8820 non-null   int64
#  8   Gender                   8820 non-null   object
#  9   JobLevel                 8820 non-null   int64
#  10  JobRole                  8820 non-null   object
#  11  MaritalStatus            8820 non-null   object
#  12  MonthlyIncome            8820 non-null   int64
#  13  NumCompaniesWorked       8782 non-null   float64
# ...

# %%
df_managersurvey
# Out:
#       EmployeeID  JobInvolvement  PerformanceRating  SurveyDate
# 0              1               3                  3  2015-12-31
# 1              2               2                  4  2015-12-31
# 2              3               3                  3  2015-12-31
# 3              4               2                  3  2015-12-31
# 4              5               3                  3  2015-12-31
# ...          ...             ...                ...         ...
# 8815        4406               3                  3  2016-12-31
# 8816        4407               2                  3  2016-12-31
# 8817        4408               3                  4  2016-12-31
# 8818        4409               2                  3  2016-12-31
# 8819        4410               4                  3  2016-12-31
#
# [8820 rows x 4 columns]

# %%
df_managersurvey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8820 entries, 0 to 8819
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EmployeeID         8820 non-null   int64
#  1   JobInvolvement     8820 non-null   int64
#  2   PerformanceRating  8820 non-null   int64
#  3   SurveyDate         8820 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 275.8+ KB

# %%
df_employeesurvey
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 0              1                      3.0              4.0              2.0
# 1              2                      3.0              2.0              4.0
# 2              3                      2.0              2.0              1.0
# 3              4                      4.0              4.0              3.0
# 4              5                      4.0              1.0              3.0
# ...          ...                      ...              ...              ...
# 8815        4406                      4.0              1.0              3.0
# 8816        4407                      4.0              4.0              3.0
# 8817        4408                      1.0              3.0              3.0
# 8818        4409                      4.0              1.0              3.0
# 8819        4410                      1.0              3.0              NaN
#
#       DateSurvey
# 0     2015-12-31
# 1     2015-12-31
# ...

# %%
df_employeesurvey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8820 entries, 0 to 8819
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               8820 non-null   int64
#  1   EnvironmentSatisfaction  8770 non-null   float64
#  2   JobSatisfaction          8780 non-null   float64
#  3   WorkLifeBalance          8744 non-null   float64
#  4   DateSurvey               8820 non-null   object
# dtypes: float64(3), int64(1), object(1)
# memory usage: 344.7+ KB

# %%
df_retirement
# Out:
#      EmployeeID Attrition retirementDate retirementType resignationReason
# 0             2       Yes     2016-10-15    Resignation            Others
# 1             7       Yes     2016-07-20    Resignation            Stress
# 2            14       Yes     2016-11-08    Resignation            Others
# 3            29       Yes     2016-10-15    Resignation            Others
# 4            31       Yes     2016-02-08    Resignation            Salary
# ..          ...       ...            ...            ...               ...
# 706        4382       Yes     2015-04-18    Resignation            Salary
# 707        4387       Yes     2015-09-16    Resignation            Others
# 708        4389       Yes     2015-05-24    Resignation            Others
# 709        4392       Yes     2015-02-26          Fired               NaN
# 710        4403       Yes     2015-01-26    Resignation            Stress
#
# [711 rows x 5 columns]

# %%
df_retirement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 711 entries, 0 to 710
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EmployeeID         711 non-null    int64
#  1   Attrition          711 non-null    object
#  2   retirementDate     711 non-null    object
#  3   retirementType     711 non-null    object
#  4   resignationReason  641 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 27.9+ KB

# %%
df_retirement['Attrition'].unique()
# Out:
# array(['Yes'], dtype=object)

# %%
import a_funciones as fn ### importar modulo de  funciones
from a_funciones import * ### importar toddas llas funciones del archivo

# %%
import sqlite3 as sql

# %%
con=sql.connect('tabla_completa.db')  ### crea base de datos
cur=con.cursor()  ### para ejecutar consultas en la base de datos

# %%
cur.execute("Select name from sqlite_master where type='table'") ### consultar bases de datos
cur.fetchall()
# Out:
# [('fulldata',),
#  ('generaldata',),
#  ('managersurvey',),
#  ('employeesurvey',),
#  ('retirement',)]

# %%
general_data=pd.read_csv('general_data.csv')
general_data.to_sql('generaldata',con,index=False, if_exists='replace') ### para llevar un data frame de pandas a SQL

managersurvey=pd.read_csv('manager_survey.csv')
managersurvey.to_sql('managersurvey',con,index=False, if_exists='replace') 

employee_survey_data=pd.read_csv('employee_survey_data.csv')
employee_survey_data.to_sql('employeesurvey', con,index=False, if_exists='replace')

retirement_info=pd.read_csv('retirement_info.csv')
retirement_info.to_sql('retirement',con, index=False, if_exists='replace')
# Out:
# 711

# %%
pd.read_sql(""" select * from generaldata
""", con=con)
# Out:
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 0      51      Travel_Rarely                   Sales                 6
# 1      31  Travel_Frequently  Research & Development                10
# 2      32  Travel_Frequently  Research & Development                17
# 3      38         Non-Travel  Research & Development                 2
# 4      32      Travel_Rarely  Research & Development                10
# ...   ...                ...                     ...               ...
# 8815   42      Travel_Rarely  Research & Development                 5
# 8816   29      Travel_Rarely  Research & Development                 2
# 8817   25      Travel_Rarely  Research & Development                25
# 8818   42      Travel_Rarely                   Sales                18
# 8819   40      Travel_Rarely  Research & Development                28
#
#       Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# ...

# %%
pd.read_sql(""" select InfoDate, count(distinct EmployeeID) as conteo
from generaldata
group by InfoDate
""", con=con)
# Out:
#      InfoDate  conteo
# 0  2015-12-31    4410
# 1  2016-12-31    4410

# %%
pd.read_sql(""" select * from managersurvey
""", con=con)
# Out:
#       EmployeeID  JobInvolvement  PerformanceRating  SurveyDate
# 0              1               3                  3  2015-12-31
# 1              2               2                  4  2015-12-31
# 2              3               3                  3  2015-12-31
# 3              4               2                  3  2015-12-31
# 4              5               3                  3  2015-12-31
# ...          ...             ...                ...         ...
# 8815        4406               3                  3  2016-12-31
# 8816        4407               2                  3  2016-12-31
# 8817        4408               3                  4  2016-12-31
# 8818        4409               2                  3  2016-12-31
# 8819        4410               4                  3  2016-12-31
#
# [8820 rows x 4 columns]

# %%
pd.read_sql(""" select * from employeesurvey
""", con=con)
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 0              1                      3.0              4.0              2.0
# 1              2                      3.0              2.0              4.0
# 2              3                      2.0              2.0              1.0
# 3              4                      4.0              4.0              3.0
# 4              5                      4.0              1.0              3.0
# ...          ...                      ...              ...              ...
# 8815        4406                      4.0              1.0              3.0
# 8816        4407                      4.0              4.0              3.0
# 8817        4408                      1.0              3.0              3.0
# 8818        4409                      4.0              1.0              3.0
# 8819        4410                      1.0              3.0              NaN
#
#       DateSurvey
# 0     2015-12-31
# 1     2015-12-31
# ...

# %%
pd.read_sql(""" select * from retirement
""", con=con)
# Out:
#      EmployeeID Attrition retirementDate retirementType resignationReason
# 0             2       Yes     2016-10-15    Resignation            Others
# 1             7       Yes     2016-07-20    Resignation            Stress
# 2            14       Yes     2016-11-08    Resignation            Others
# 3            29       Yes     2016-10-15    Resignation            Others
# 4            31       Yes     2016-02-08    Resignation            Salary
# ..          ...       ...            ...            ...               ...
# 706        4382       Yes     2015-04-18    Resignation            Salary
# 707        4387       Yes     2015-09-16    Resignation            Others
# 708        4389       Yes     2015-05-24    Resignation            Others
# 709        4392       Yes     2015-02-26          Fired              None
# 710        4403       Yes     2015-01-26    Resignation            Stress
#
# [711 rows x 5 columns]

# %%
pd.read_sql("""
select strftime('%Y',retirementDate) as year, count(distinct EmployeeID) as conteo
from retirement
group by year
""", con=con)
# Out:
#    year  conteo
# 0  2015      61
# 1  2016     650

# %%
#df_consul=pd.read_sql("""select * from generaldata a left join employeesurvey b on a.EmployeeID=b.EmployeeID and a.InfoDate=b.DateSurvey left join retirement c on a.EmployeeID=c.EmployeeID
            #""", con)

# %%
df_consulta= ("""
select a.*, b.EnvironmentSatisfaction, b.JobSatisfaction, b.WorkLifeBalance from generaldata a left join employeesurvey b on a.EmployeeID=b.EmployeeID and a.InfoDate=b.DateSurvey 
  select c.JobInvolvement, c.PerformanceRating, c.SurveyDate left join managersurvey c on a.EmployeeID=c.EmployeeID and a.InfoDate=c.SurveyDate
              """)

# %%
df_consul = pd.read_sql("""
SELECT 
    a.*,  
    b.EnvironmentSatisfaction, 
    b.JobSatisfaction, 
    b.WorkLifeBalance,
    b.DateSurvey,
    c.JobInvolvement, 
    c.PerformanceRating, 
    c.SurveyDate,
    d.Attrition,
    d.retirementDate,
    d.retirementType,
    d.resignationReason
    
FROM 
    generaldata a 
LEFT JOIN 
    employeesurvey b 
ON 
    a.EmployeeID = b.EmployeeID AND a.InfoDate = b.DateSurvey 
LEFT JOIN 
    managersurvey c 
ON 
    a.EmployeeID = c.EmployeeID AND a.InfoDate = c.SurveyDate
LEFT JOIN 
    retirement d 
ON 
    a.EmployeeID = d.EmployeeID
""", con)

# %%
df_consul
# Out:
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 0      51      Travel_Rarely                   Sales                 6
# 1      31  Travel_Frequently  Research & Development                10
# 2      32  Travel_Frequently  Research & Development                17
# 3      38         Non-Travel  Research & Development                 2
# 4      32      Travel_Rarely  Research & Development                10
# ...   ...                ...                     ...               ...
# 8815   42      Travel_Rarely  Research & Development                 5
# 8816   29      Travel_Rarely  Research & Development                 2
# 8817   25      Travel_Rarely  Research & Development                25
# 8818   42      Travel_Rarely                   Sales                18
# 8819   40      Travel_Rarely  Research & Development                28
#
#       Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# ...

# %%
df_consul=df_consul.drop(df_consul.columns[-3:], axis=1)

# %%
df_consul
# Out:
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 0      51      Travel_Rarely                   Sales                 6
# 1      31  Travel_Frequently  Research & Development                10
# 2      32  Travel_Frequently  Research & Development                17
# 3      38         Non-Travel  Research & Development                 2
# 4      32      Travel_Rarely  Research & Development                10
# ...   ...                ...                     ...               ...
# 8815   42      Travel_Rarely  Research & Development                 5
# 8816   29      Travel_Rarely  Research & Development                 2
# 8817   25      Travel_Rarely  Research & Development                25
# 8818   42      Travel_Rarely                   Sales                18
# 8819   40      Travel_Rarely  Research & Development                28
#
#       Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# ...

# %%
df_consul.drop('InfoDate', axis=1, inplace=True)

# %%
df_consul.drop('DateSurvey', axis=1, inplace=True)

# %%
df_consul
# Out:
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 0      51      Travel_Rarely                   Sales                 6
# 1      31  Travel_Frequently  Research & Development                10
# 2      32  Travel_Frequently  Research & Development                17
# 3      38         Non-Travel  Research & Development                 2
# 4      32      Travel_Rarely  Research & Development                10
# ...   ...                ...                     ...               ...
# 8815   42      Travel_Rarely  Research & Development                 5
# 8816   29      Travel_Rarely  Research & Development                 2
# 8817   25      Travel_Rarely  Research & Development                25
# 8818   42      Travel_Rarely                   Sales                18
# 8819   40      Travel_Rarely  Research & Development                28
#
#       Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# ...

# %%
df_consul['SurveyDate']=pd.to_datetime(df_consul['SurveyDate'])
df_consul['AñoEncu'] =df_consul['SurveyDate'].dt.year

# %%
df_consul['AñoEncu'] = df_consul['AñoEncu'].astype(object)

# %%
df_consul.dtypes
# Out:
# Age                                 int64
# BusinessTravel                     object
# Department                         object
# DistanceFromHome                    int64
# Education                           int64
# EducationField                     object
# EmployeeCount                       int64
# EmployeeID                          int64
# Gender                             object
# JobLevel                            int64
# JobRole                            object
# MaritalStatus                      object
# MonthlyIncome                       int64
# NumCompaniesWorked                float64
# Over18                             object
# PercentSalaryHike                   int64
# StandardHours                       int64
# StockOptionLevel                    int64
# TotalWorkingYears                 float64
# TrainingTimesLastYear               int64
# YearsAtCompany                      int64
# YearsSinceLastPromotion             int64
# ...

# %%
df_consul.drop('SurveyDate', axis=1, inplace=True)

# %%
df_consul
# Out:
#       Age     BusinessTravel              Department  DistanceFromHome  \
# 0      51      Travel_Rarely                   Sales                 6
# 1      31  Travel_Frequently  Research & Development                10
# 2      32  Travel_Frequently  Research & Development                17
# 3      38         Non-Travel  Research & Development                 2
# 4      32      Travel_Rarely  Research & Development                10
# ...   ...                ...                     ...               ...
# 8815   42      Travel_Rarely  Research & Development                 5
# 8816   29      Travel_Rarely  Research & Development                 2
# 8817   25      Travel_Rarely  Research & Development                25
# 8818   42      Travel_Rarely                   Sales                18
# 8819   40      Travel_Rarely  Research & Development                28
#
#       Education EducationField  EmployeeCount  EmployeeID  Gender  JobLevel  \
# ...

# %%
df_consul.to_csv('consulta.csv', index=False)

# %%
df_consul['Attrition'].unique()
# Out:
# array([None, 'Yes'], dtype=object)

# %%
df_consul.columns
# Out:
# Index(['Age', 'BusinessTravel', 'Department', 'DistanceFromHome', 'Education',
#        'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender', 'JobLevel',
#        'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'Over18', 'PercentSalaryHike', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance',
#        'JobInvolvement', 'PerformanceRating', 'Attrition', 'AñoEncu'],
#       dtype='object')
